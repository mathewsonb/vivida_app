# %% [markdown]
# # App Development and Function Testing
#
# -

# %%
# import required libraries and modules
import pandas as pd
import numpy as np
import secrets
import sys, os, winreg

# %% [markdown]
# ## Generate a 32-Character SALT
#
# Use this function to generate unique 32-Character SALT codes.
#
# The first code should be the last, and will be stored in the database for future decryption and anonymous longitudinal linking.

# %%
# UNCOMMENT AS NEEDED
# ====================
# # generate a 32-character SALT
# SALT = secrets.token_urlsafe(24)[:32]

# # preview the generated sequence
# print(SALT)

# %% [markdown]
# ## Inspect Environment Variables

# %%
# use the 'os' module to view system environment variables
display(os.environ['PATH'])
